# %%
import geopandas
import descartes
import matplotlib
import matplotlib.pyplot as plt

# %%
df = geopandas.read_file("../London-wards-2018_ESRI/London_Ward.shp")

f, ax = plt.subplots(1, figsize=(12, 12))
ax = df.plot(ax=ax, alpha=0.1)
plt.show()
